# %% [markdown]
# # Case study summary
# This document compares MC (Muskingum-Cunge) computed values in WRF-HYDRO against those from a Python routing tool. The Python routing tool consists of NHD traversal tools (i.e., nhd_network_traversal.py, nhd_network_utilities.py, nhd_reach_utilities.py, compute_nhd_routing_v2.py) and MC standalone tools (i.e., channel_routing_tools.py, MCsingleSegStime_f2py_noIC_clean.f90, and varSingleSegStime_f2py_noIC_clean.f90)
#
# # 1. Purpose
# This case study investigates whether or not MC source code carved out of WRF-HYDRO and then transformed into a Python extension module generates the same results as WRF-HYDRO.
#
# # 2. Study Area
# Pocono Basin where the Lehigh River in PL flows through was chosen mainly because WRF-HYDRO was applied to this basin by Austin Raney and thus its MC-computed results are readily available including lateral inflows.  Out of the entire applied segments marked by 374 red circles in Figure 1, 54 segments, marked by green circles, were chosen for this study mainly because this sub-NHD has no reservoirs and all of its segments have computed flow and depth values by MC of WRF-HYDRO.
#
# ![fig1.JPG](attachment:fig1.JPG)
# Figure 1. Study area
#
# # 3. Method and Results
# With 300 sec time interval and 12 hrs total time period, total 144 time steps were used in this study.  Overall relative errors in flow as well as depth are less than 0.05% or 0.0005, which is safely to be considered to be identical, factoring in primarily propagation of rounding errors differently occurring in the two model platforms.
#
# ![fig2.JPG](attachment:fig2.JPG)
# Figure 2. Flow computed in WRF-HYDRO and relative errors computed between WRF-HYDRO and the Python routing tool.   Link 4186169 is used for Figure 2, as indicated in Figure 4.  The two relative error graphs don’t appear here because they are simply zeros.
#
# ![fig3.JPG](attachment:fig3.JPG)
# Figure 3. Flow computed in WRF-HYDRO and relative errors computed between WRF-HYDRO and the Python routing tool.   Link 4185243 is used for Figure 2, as indicated in Figure 4.
#
# ![fig4.JPG](attachment:fig4.JPG)
# Figure 4. Study basin area with all the segment ID represented by its link number.

# %%
## Basic imports
import sys
import os
import time

# WARNING: These global declarations cause the parallel implementation to 
# crash when executed on Windows
connections = None
networks = None
flowdepthvel = None

from sys import platform
if platform == "linux" or platform == "linux2":
    pass
elif platform == "darwin":
    pass
elif platform == "win32":
    print('The parallel version of compute_nhd_routing.py will not execute as currently')
    print('written due to the lack of a fork() capability in the windows OS.')
    print('For parallel execution, please us a *nix OS.')
    print('\nexiting...')
    sys.exit()
    # Some useful references:
    # https://stackoverflow.com/questions/985281/what-is-the-closest-thing-windows-has-to-fork/985525#985525
    # https://stackoverflow.com/questions/8220108/how-do-i-check-the-operating-system-in-python
    # https://stackoverflow.com/questions/6596617/python-multiprocess-diff-between-windows-and-linux

ENV_IS_CL = False
if ENV_IS_CL: root = '/content/wrf_hydro_nwm_public/trunk/NDHMS/dynamic_channel_routing/'
elif not ENV_IS_CL: 
    sys.setrecursionlimit(4000)
#     root = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
    root = os.path.dirname((os.path.abspath('')))
    sys.path.append(os.path.join(root, r'src', r'python_framework'))
    sys.path.append(os.path.join(root, r'src', r'python_routing_v02')) #by Dong Ha
    fortran_source_dir = os.path.join(root, r'src', r'fortran_routing', r'mc_pylink_v00', r'MC_singleSeg_singleTS')
    sys.path.append(fortran_source_dir)

## F2PY Muskingum Cunge module
mc_f2py= True
if mc_f2py:
    try:
        import subprocess

        f2py_call = []
        f2py_call.append(r'f2py3')
        f2py_call.append(r'-c')
        f2py_call.append(r'varPrecision.f90')
        f2py_call.append(r'varSingleSegStime_f2py_noIC_clean.f90')
        f2py_call.append(r'MCsingleSegStime_f2py_noIC_clean.f90')
        f2py_call.append(r'-m')
        f2py_call.append(r'mc_sseg_stime_noIC')
        subprocess.run(f2py_call, cwd=fortran_source_dir,
                       stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    except Exception as e:
        print(e)

## network and reach utilities
import nhd_network_utilities as nnu
import nhd_reach_utilities as nru
import channel_routing_tools as crt

## Muskingum Cunge
import numpy as np

def mc_route_network(
          terminal_segment = None
        , network = None
        , supernetwork_data = None
        , outputpath = "."
        , nts = None
        , dt_mc= None
        , latflow= None
#         , connections = None
        , verbose = False
        , debuglevel = 0
        ):

    global connections
    global flowdepthvel 

    if verbose: print(f"Executing simulation on network {terminal_segment} beginning with streams of order {network['maximum_reach_seqorder']}")

    ##------------------------------------------------------------------------
    ## Compute ordered_reaches and last_segment_reach for all the segments of
    ## reach referenced by head_segment
    ##------------------------------------------------------------------------
    ordered_reaches = {}
    # Start: By Dong Ha
    last_segment_reach={}
    #End    
    for head_segment, reach in network['reaches'].items():
        if reach['seqorder'] not in ordered_reaches:
            ordered_reaches.update({reach['seqorder']:[]}) #TODO: Should this be a set/dictionary?
        ordered_reaches[reach['seqorder']].append([head_segment, reach])
        # Start: By Dong Ha
        seg_list=list(reach['segments_list'])
        lastseg=seg_list[0]
        last_segment_reach[head_segment]= lastseg
        # End 

    ##-------------------------------------------
    ## From jorder= maximum_reach_order to zero
    ##     From each reach that has jorder
    ##         run mc routing of a chosen scheme
    ##
    ## Output-> flowdepthvel
    ##--------------------------------------------
    #Note that not networks but network that takes networks values corresponding to 'terminal_segment' keys.
    #Also, network here takes 'terminal_segment' key only at the lower end of a network.      
    for x in range(network['maximum_reach_seqorder'],-1,-1):    
        
        for head_segment, reach in ordered_reaches[x]:       
#             print(latflow)
            ## START: run MC over each segment over entire timesteps
            crt.mc_tlp_over_seg(
                            connections= connections 
                            ,supernetwork_data= supernetwork_data
                            ,reach= reach
                            ,last_segment_reach= last_segment_reach
                            ,nts= nts
                            ,dt_mc= dt_mc
                            ,latflow= latflow
                            ,flowdepthvel= flowdepthvel
                            )            
            ## END: MC-computed results for flow, vel, and depth are stored in 'flowdepthvel'
           
            ## Start: Only for printing results
            seg_list=list(reach['segments_list'])
            seg_list=seg_list[::-1] #to reversed order
            ncomp= len(reach['segments_list'])
            for seg in range(0,ncomp):  
                segID= seg_list[seg]
                for ts in range (0,nts):
                    print(f"ts {ts} head_segment {head_segment} segINDEX {seg} segID {segID} \
                            FNL:ql qdc vel depth {flowdepthvel[segID]['qlat'][ts]} {flowdepthvel[segID]['flow'][ts]} \
                            {flowdepthvel[segID]['vel'][ts]} {flowdepthvel[segID]['depth'][ts]}")  
            with open(os.path.join(outputpath,r"flowdepthvel.txt"),"a") as mc_result:
                for seg in range(0,ncomp):  
                    segID= seg_list[seg]
                    for ts in range (0,nts):
                        mc_result.write("%s %s %s %s %s %s\n" % (ts, segID, flowdepthvel[segID]['qlat'][ts], 
                            flowdepthvel[segID]['flow'][ts], flowdepthvel[segID]['vel'][ts], flowdepthvel[segID]['depth'][ts]))        
              ## End  
                          
def main():

    global connections
    global networks
    global flowdepthvel

    verbose = True
    debuglevel = 0
    showtiming = True

    test_folder = os.path.join(root, r'test')
    geo_input_folder = os.path.join(test_folder, r'input', r'geo')

    #TODO: Make these commandline args
    # supernetwork= 'Pocono_TEST1'
    supernetwork= 'Pocono_TEST2'
    """##NHD Subset (Brazos/Lower Colorado)"""
    # supernetwork = 'Brazos_LowerColorado_ge5'
    """##NHD CONUS order 5 and greater"""
    # supernetwork = 'CONUS_ge5'
    """These are large -- be careful"""
    # supernetwork = 'Mainstems_CONUS'
    # supernetwork = 'CONUS_FULL_RES_v20'
    # supernetwork = 'CONUS_Named_Streams' #create a subset of the full resolution by reading the GNIS field
    # supernetwork = 'CONUS_Named_combined' #process the Named streams through the Full-Res paths to join the many hanging reaches

    if verbose: print('creating supernetwork connections set')
    if showtiming: start_time = time.time()
    #STEP 1
    supernetwork_data, supernetwork_values = nnu.set_networks(
        supernetwork = supernetwork
        , geo_input_folder = geo_input_folder
        , verbose = False
        # , verbose = verbose
        , debuglevel = debuglevel
        )
    if verbose: print('supernetwork connections set complete')
    if showtiming: print("... in %s seconds." % (time.time() - start_time))

    #STEP 2
    if showtiming: start_time = time.time()
    if verbose: print('organizing connections into networks and reaches ...')
    networks = nru.compose_networks(
        supernetwork_values
        , verbose = False
        # , verbose = verbose
        , debuglevel = debuglevel
        , showtiming = showtiming
        )
    if verbose: print('reach organization complete')
    if showtiming: print("... in %s seconds." % (time.time() - start_time))
    

    #STEP 3: Route NHD streamflow
    if showtiming: start_time = time.time()
    executiontype = 'serial' # 'parallel'

    if verbose: print('executing serial computation on ordered reaches ...')
    connections = supernetwork_values[0]

    nts = 144  # number of timestep = 1140 * 60(model timestep) = 86400 = day
    dt_mc= 300.0 # time interval for MC
    
    # Lateral flow
    ## test 1. Take lateral flow from wrf-hydro output from Pocono Basin
    qlcol=54
    qlrow=145
    ql=np.zeros((qlrow,qlcol))
    ql_input_folder= os.path.join(root,r'test/input/geo/PoconoSampleData2/Pocono_ql_testsamp1_nwm_mc.txt')
    print(ql_input_folder)
    for j in range(0, qlcol):
        ql[0,j]=np.loadtxt(ql_input_folder, max_rows=1,usecols=(j+2)) 
        ql[1:,j]=np.loadtxt(ql_input_folder, skiprows=2,usecols=(j+2))
    latflow={}
    for j in range(0,qlcol):
        latflow.update({ql[0,j]:{'lateralflow':ql[1:,j]}})
       
    flowdepthvel = {connection:{'flow':np.zeros(nts)
                                , 'depth':np.zeros(nts)
                                , 'vel':np.zeros(nts)
                                , 'qlat':np.zeros(nts)}
                               for connection in connections}  

    if executiontype == 'serial':
        iter=0
        for terminal_segment, network in networks.items():
            if showtiming: network_start_time = time.time()
#             iter=iter+1
#             print(f"terminal_segment iter-> {iter}")

            ## run MC to route network 
            mc_route_network(
                  terminal_segment = terminal_segment
                , network = network
                , supernetwork_data = supernetwork_data
                , outputpath = os.path.join(root, r"test", r"output", r"text")
                , nts = nts
                , dt_mc= dt_mc
                , latflow= latflow                
#         , connections = None
                , verbose = False
                , debuglevel = 0
            )
        
#             if verbose: print(f'{terminal_segment} completed')
#             if showtiming: print("... in %s seconds." % (time.time() - network_start_time))
        
#     if verbose: print('ordered reach computation complete')
#     if showtiming: print("... in %s seconds." % (time.time() - start_time))

if __name__ == '__main__':
    main()
# Out:
# creating supernetwork connections set
# supernetwork connections set complete
# ... in 8.470447063446045 seconds.
# organizing connections into networks and reaches ...
# reach organization complete
# ... in 0.0004897117614746094 seconds.
# executing serial computation on ordered reaches ...
# /home/james.halgren/git/t-route-jsh/test/input/geo/PoconoSampleData2/Pocono_ql_testsamp1_nwm_mc.txt
# ts 0 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.20244789123535156                             0.1462530642747879 0.012524466961622238
# ts 1 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.4985886812210083                             0.23942650854587555 0.02665754221379757
# ts 2 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.7377897500991821                             0.33711010217666626 0.04545453190803528
# ts 3 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.8875131607055664                             0.4438540041446686 0.07045453041791916
# ts 4 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9845608472824097                             0.9619055390357971 0.26210057735443115
# ts 5 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937636852264404                             1.1816247701644897 0.3826943039894104
# ts 6 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937891960144043                             1.424849271774292 0.5456566214561462
# ts 7 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937999248504639                             1.1827138662338257 0.38335463404655457
# ts 8 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937999248504639                             1.4249085187911987 0.5457000732421875
# ts 9 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937998652458191                             1.1827083826065063 0.38335129618644714
# ts 10 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937999248504639                             1.42490816116333 0.5456998348236084
# ts 11 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.9937999844551086 0.9937998652458191                             1.182708501815796 0.3833513557910919
# ts 12 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.7339574098587036                             1.3692620992660522 0.5056767463684082
# ts 13 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.6153530478477478                             1.0083889961242676 0.28553780913352966
# ts 14 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.6077098250389099                             1.0155161619186401 0.2892286777496338
# ts 15 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.6072319746017456                             1.015273094177246 0.2891024053096771
# ts 16 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.6072019934654236                             1.0152575969696045 0.28909432888031006
# ts 17 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.6072000861167908                             1.0152565240859985 0.2890937924385071
# ts 18 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.607200026512146                             1.015256404876709 0.2890937626361847
# ts 19 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.607200026512146                             1.015256404876709 0.2890937626361847
# ts 20 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.607200026512146                             1.015256404876709 0.2890937626361847
# ts 21 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.607200026512146                             1.015256404876709 0.2890937626361847
# ts 22 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.607200026512146                             1.015256404876709 0.2890937626361847
# ts 23 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.607200026512146 0.607200026512146                             1.015256404876709 0.2890937626361847
# ts 24 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.47951972484588623                             0.9370726943016052 0.2500273287296295
# ts 25 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.4661649763584137                             0.9330739974975586 0.24811217188835144
# ts 26 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.4648453891277313                             0.9322293400764465 0.24770866334438324
# ts 27 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.4647144079208374                             0.9321450591087341 0.24766843020915985
# ts 28 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470144391059875                             0.9321368336677551 0.2476644515991211
# ts 29 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.4647001326084137                             0.9321358799934387 0.24766404926776886
# ts 30 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470001339912415                             0.9321357607841492 0.24766398966312408
# ts 31 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470001339912415                             0.9321357607841492 0.24766398966312408
# ts 32 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470001339912415                             0.9321357607841492 0.24766398966312408
# ts 33 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470001339912415                             0.9321357607841492 0.24766398966312408
# ts 34 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470001339912415                             0.9321357607841492 0.24766398966312408
# ts 35 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.46470001339912415 0.46470001339912415                             0.9321357607841492 0.24766398966312408
# ts 36 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.37826070189476013                             0.8674930930137634 0.2178357094526291
# ts 37 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3664615750312805                             0.8595862984657288 0.21432843804359436
# ts 38 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.36478081345558167                             0.8584787845611572 0.21383965015411377
# ts 39 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3645402193069458                             0.8583201169967651 0.21376964449882507
# ts 40 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.364505797624588                             0.8582974076271057 0.2137596309185028
# ts 41 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.36450085043907166                             0.8582941293716431 0.2137582004070282
# ts 42 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.36450013518333435                             0.8582936525344849 0.2137579768896103
# ts 43 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3645000159740448                             0.8582936525344849 0.2137579619884491
# ts 44 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3644999861717224                             0.8582935929298401 0.2137579470872879
# ts 45 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3644999861717224                             0.8582935929298401 0.2137579470872879
# ts 46 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3644999861717224                             0.8582935929298401 0.2137579470872879
# ts 47 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.3644999861717224 0.3644999861717224                             0.8582935929298401 0.2137579470872879
# ts 48 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.3031619191169739                             0.8062100410461426 0.19144406914710999
# ts 49 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.2928733229637146                             0.7978047132492065 0.1879650205373764
# ts 50 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.29108089208602905                             0.7963529229164124 0.18736757338047028
# ts 51 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.29076680541038513                             0.7960985898971558 0.18726292252540588
# ts 52 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.29071173071861267                             0.7960538268089294 0.18724457919597626
# ts 53 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.29070207476615906                             0.7960460782051086 0.1872413605451584
# ts 54 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.29070034623146057                             0.7960445880889893 0.18724079430103302
# ts 55 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.2907000482082367                             0.7960443496704102 0.18724067509174347
# ts 56 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.2907000184059143                             0.7960443496704102 0.18724067509174347
# ts 57 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.2906999886035919                             0.7960443496704102 0.18724066019058228
# ts 58 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.2906999886035919                             0.7960443496704102 0.18724066019058228
# ts 59 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.2906999886035919 0.2906999886035919                             0.7960443496704102 0.18724066019058228
# ts 60 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.246080681681633                             0.751483142375946 0.16939136385917664
# ts 61 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.2372688353061676                             0.7429211139678955 0.16606828570365906
# ts 62 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.2354670763015747                             0.7411727905273438 0.16539396345615387
# ts 63 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.235096275806427                             0.7408127784729004 0.16525526344776154
# ts 64 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23501986265182495                             0.7407385110855103 0.16522668302059174
# ts 65 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23500409722328186                             0.7407233119010925 0.16522078216075897
# ts 66 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.2350008338689804                             0.7407200932502747 0.16521957516670227
# ts 67 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23500017821788788                             0.7407194972038269 0.16521932184696198
# ts 68 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23500004410743713                             0.7407193779945374 0.1652192771434784
# ts 69 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23500002920627594                             0.7407193779945374 0.1652192771434784
# ts 70 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23500001430511475                             0.7407193779945374 0.1652192622423172
# ts 71 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.23499999940395355 0.23500001430511475                             0.7407193779945374 0.1652192622423172
# ts 72 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.20172280073165894                             0.7020529508590698 0.15067332983016968
# ts 73 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19419819116592407                             0.6934833526611328 0.14754216372966766
# ts 74 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19244080781936646                             0.6914747357368469 0.14681310951709747
# ts 75 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19202743470668793                             0.6910017728805542 0.14664168655872345
# ts 76 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19193004071712494                             0.690890371799469 0.14660128951072693
# ts 77 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19190707802772522                             0.6908640265464783 0.14659176766872406
# ts 78 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19190166890621185                             0.6908578276634216 0.14658953249454498
# ts 79 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19190040230751038                             0.6908563375473022 0.146588996052742
# ts 80 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.1919001042842865                             0.6908560395240784 0.14658887684345245
# ts 81 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19190001487731934                             0.690855860710144 0.14658883213996887
# ts 82 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19189999997615814                             0.690855860710144 0.14658883213996887
# ts 83 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.19189999997615814 0.19189999997615814                             0.690855860710144 0.14658883213996887
# ts 84 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.1666768491268158                             0.6570462584495544 0.1345994472503662
# ts 85 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.16027498245239258                             0.6485945582389832 0.1316823810338974
# ts 86 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.1586000919342041                             0.6463676691055298 0.13091908395290375
# ts 87 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.158158540725708                             0.6457794904708862 0.13071782886981964
# ts 88 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15804190933704376                             0.6456239223480225 0.1306646466255188
# ts 89 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.1580110788345337                             0.6455827951431274 0.130650594830513
# ts 90 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15800292789936066                             0.6455720067024231 0.13064688444137573
# ts 91 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15800078213214874                             0.6455691456794739 0.13064591586589813
# ts 92 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15800020098686218                             0.645568311214447 0.13064563274383545
# ts 93 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15800005197525024                             0.6455681324005127 0.13064557313919067
# ts 94 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15800002217292786                             0.6455681324005127 0.13064555823802948
# ts 95 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.15800000727176666 0.15800000727176666                             0.6455681324005127 0.13064555823802948
# ts 96 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.1385757029056549                             0.6157407164573669 0.1206437274813652
# ts 97 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.1331230252981186                             0.6074648499488831 0.11793792992830276
# ts 98 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13154786825180054                             0.6050507426261902 0.11715427041053772
# ts 99 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13108915090560913                             0.6043457388877869 0.11692589521408081
# ts 100 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13095524907112122                             0.6041398048400879 0.11685921996831894
# ts 101 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13091614842414856                             0.6040796637535095 0.11683975160121918
# ts 102 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13090471923351288                             0.604062020778656 0.11683405935764313
# ts 103 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13090138137340546                             0.6040568947792053 0.11683239787817001
# ts 104 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13090041279792786                             0.6040554046630859 0.11683192104101181
# ts 105 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13090011477470398                             0.6040549874305725 0.11683177202939987
# ts 106 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13090002536773682                             0.604054868221283 0.11683173477649689
# ts 107 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.13089999556541443 0.13090001046657562                             0.604054868221283 0.11683172732591629
# ts 108 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.11585307121276855                             0.5777369141578674 0.10846424102783203
# ts 109 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.11123546212911606                             0.5697376728057861 0.1059802696108818
# ts 110 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10977959632873535                             0.5671856999397278 0.1051936149597168
# ts 111 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10931670665740967                             0.5663714408874512 0.10494320839643478
# ts 112 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10916914790868759                             0.5661115646362305 0.10486335307359695
# ts 113 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10912206768989563                             0.5660285949707031 0.10483785718679428
# ts 114 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10910704731941223                             0.5660021305084229 0.10482972860336304
# ts 115 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10910224914550781                             0.5659937262535095 0.10482713580131531
# ts 116 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10910072177648544                             0.5659909844398499 0.10482630133628845
# ts 117 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10910023748874664                             0.565990149974823 0.10482605546712875
# ts 118 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10910007357597351                             0.5659898519515991 0.104825958609581
# ts 119 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.10909999907016754 0.10910002887248993                             0.5659898519515991 0.1048259362578392
# ts 120 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.0973396748304367                             0.5426846146583557 0.09778272360563278
# ts 121 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09343159198760986                             0.5350036025047302 0.09551206976175308
# ts 122 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09209936112165451                             0.5323501229286194 0.09473345428705215
# ts 123 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09164127707481384                             0.5314338803291321 0.09446527063846588
# ts 124 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09148330241441727                             0.5311173796653748 0.09437272697687149
# ts 125 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09142877161502838                             0.5310080051422119 0.09434077143669128
# ts 126 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09140993654727936                             0.5309702754020691 0.09432972967624664
# ts 127 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09140343219041824                             0.5309572219848633 0.09432591497898102
# ts 128 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09140118956565857                             0.5309527516365051 0.09432459622621536
# ts 129 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09140041470527649                             0.5309511423110962 0.09432414919137955
# ts 130 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.091400146484375                             0.5309506058692932 0.09432398527860641
# ts 131 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.09139999747276306 0.09140005707740784                             0.5309504866600037 0.09432394057512283
# ts 132 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.08212995529174805                             0.5102317929267883 0.0883588194847107
# ts 133 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07882007956504822                             0.5028882026672363 0.08628783375024796
# ts 134 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07760947942733765                             0.5001628994941711 0.08552499860525131
# ts 135 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07716277241706848                             0.49915215373039246 0.0852428749203682
# ts 136 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07699741423130035                             0.49877724051475525 0.08513833582401276
# ts 137 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07693612575531006                             0.4986382722854614 0.08509958535432816
# ts 138 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07691340148448944                             0.4985866844654083 0.08508522063493729
# ts 139 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07690497487783432                             0.4985675811767578 0.08507989346981049
# ts 140 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07690184563398361                             0.49856051802635193 0.0850779116153717
# ts 141 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07690068334341049                             0.49855783581733704 0.08507717400789261
# ts 142 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07690025120973587                             0.49855682253837585 0.08507689833641052
# ts 143 head_segment 4185243 segINDEX 0 segID 4185243                             FNL:ql qdc vel depth 0.07689999788999557 0.07690009474754333                             0.4985564351081848 0.08507679402828217
# ts 0 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 0.03613242506980896                             0.06527093052864075 0.010229581035673618
# ts 1 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 0.11954694986343384                             0.11300905793905258 0.0236053429543972
# ts 2 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 0.2510364353656769                             0.16254852712154388 0.04139510542154312
# ts 3 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 0.43109130859375                             0.21668973565101624 0.0650554895401001
# ts 4 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 0.6511858701705933                             0.2770248055458069 0.09652379900217056
# ts 5 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 0.9001888632774353                             0.34475284814834595 0.13837666809558868
# ts 6 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 1.232009768486023                             0.5785337686538696 0.3402906656265259
# ts 7 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 1.4304556846618652                             0.8790729641914368 0.7436199188232422
# ts 8 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 1.6040464639663696                             0.8959493637084961 0.7711192965507507
# ts 9 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 1.7549432516098022                             0.9105678796768188 0.7953417897224426
# ts 10 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 1.8846327066421509                             0.9226045608520508 0.8155642747879028
# ts 11 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 1.5492000579833984 1.9950770139694214                             0.9325094223022461 0.8323923945426941
# ts 12 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.9276849031448364                             0.9263885617256165 0.8219733238220215
# ts 13 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.8301348686218262                             0.9174503087997437 0.80687415599823
# ts 14 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.7310237884521484                             0.9081220030784607 0.7912631034851074
# ts 15 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.647896409034729                             0.9000887870788574 0.7779404520988464
# ts 16 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.578743815422058                             0.8932410478591919 0.7666725516319275
# ts 17 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.5210115909576416                             0.8874010443687439 0.7571278214454651
# ts 18 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.472629427909851                             0.882415771484375 0.7490271925926208
# ts 19 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.4319478273391724                             0.8781564235687256 0.7421407699584961
# ts 20 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.3976433277130127                             0.8745146989822388 0.7362782955169678
# ts 21 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.3686455488204956                             0.8713994026184082 0.7312816381454468
# ts 22 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.344081997871399                             0.8687329292297363 0.7270188331604004
# ts 23 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.5946000218391418 1.323237419128418                             0.8664500713348389 0.7233790159225464
# ts 24 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.284325361251831                             0.8621100783348083 0.7164849042892456
# ts 25 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.23318612575531                             0.8563106060028076 0.707324743270874
# ts 26 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.1879810094833374                             0.8510975241661072 0.6991417407989502
# ts 27 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.1485445499420166                             0.8461747765541077 0.6914589405059814
# ts 28 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.1150110960006714                             0.8421375751495361 0.6851904988288879
# ts 29 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.0864410400390625                             0.838644802570343 0.6797909140586853
# ts 30 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.0620497465133667                             0.8356226682662964 0.6751366853713989
# ts 31 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.0411885976791382                             0.8330076336860657 0.6711223721504211
# ts 32 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.023319125175476                             0.8307445645332336 0.667658269405365
# ts 33 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 1.007991909980774                             0.8287858963012695 0.6646676659584045
# ts 34 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 0.9948300719261169                             0.8270907402038574 0.6620850563049316
# ts 35 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.4478999972343445 0.9835166931152344                             0.825623631477356 0.6598540544509888
# ts 36 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.9602850675582886                             0.8228033781051636 0.6555759906768799
# ts 37 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.9054102301597595                             0.6883301138877869 0.46843403577804565
# ts 38 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.8800520300865173                             0.8120768070220947 0.6394364833831787
# ts 39 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.841367244720459                             0.6736674308776855 0.4500395655632019
# ts 40 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.8245108127593994                             0.8042793869972229 0.6278346180915833
# ts 41 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.7987980246543884                             0.6633220911026001 0.4372999668121338
# ts 42 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.7876045107841492                             0.798785924911499 0.6197269558906555
# ts 43 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.770394504070282                             0.6561219096183777 0.4285498559474945
# ts 44 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.7629043459892273                             0.7948555946350098 0.6139600872993469
# ts 45 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.7513107657432556                             0.6511459946632385 0.42255839705467224
# ts 46 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.7462682127952576                             0.7920284271240234 0.6098292469978333
# ts 47 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.3465000092983246 0.7384222149848938                             0.6477229595184326 0.41846340894699097
# ts 48 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.7259229421615601                             0.7886943817138672 0.6049763560295105
# ts 49 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.6931679248809814                             0.634650468826294 0.4030226171016693
# ts 50 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.6775590777397156                             0.7825506329536438 0.5960869193077087
# ts 51 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.6531141996383667                             0.6225292086601257 0.3889855146408081
# ts 52 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.6422004103660583                             0.7768661975860596 0.5879234671592712
# ts 53 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.625489354133606                             0.6137499213218689 0.37898677587509155
# ts 54 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.6179987788200378                             0.7729040384292603 0.5822684168815613
# ts 55 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.60654217004776                             0.6074722409248352 0.3719233572483063
# ts 56 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.6013723015785217                             0.7700780630111694 0.5782521963119507
# ts 57 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.5934815406799316                             0.6030128002166748 0.36694958806037903
# ts 58 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.5898973941802979                             0.7679985761642456 0.5753064155578613
# ts 59 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.27320000529289246 0.5844449996948242                             0.5998601913452148 0.36345505714416504
# ts 60 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.5759412050247192                             0.7077409625053406 0.49339523911476135
# ts 61 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.5535386800765991                             0.5660408139228821 0.3271033763885498
# ts 62 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.5333787202835083                             0.5851373672485352 0.3473752439022064
# ts 63 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.5241596102714539                             0.6911437511444092 0.4720090925693512
# ts 64 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.5101564526557922                             0.5547705888748169 0.3154475688934326
# ts 65 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.4986351430416107                             0.5728256106376648 0.33423036336898804
# ts 66 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.48948681354522705                             0.5694852471351624 0.33071109652519226
# ts 67 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.48220276832580566                             0.5667822360992432 0.32787805795669556
# ts 68 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.47639408707618713                             0.5646040439605713 0.32560470700263977
# ts 69 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.47175589203834534                             0.5628500580787659 0.32378020882606506
# ts 70 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.46804845333099365                             0.5614385604858398 0.3223159909248352
# ts 71 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.21809999644756317 0.46508240699768066                             0.5603030323982239 0.32114073634147644
# ts 72 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.45439428091049194                             0.556157648563385 0.3168697655200958
# ts 73 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.43937692046165466                             0.5502091646194458 0.3107948303222656
# ts 74 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.42592987418174744                             0.5447531342506409 0.30527839064598083
# ts 75 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.4148254096508026                             0.5401483774185181 0.30066394805908203
# ts 76 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.4058320224285126                             0.5363495945930481 0.2968856692314148
# ts 77 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.3985775411128998                             0.5332383513450623 0.29381024837493896
# ts 78 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.39272540807724                             0.5306969881057739 0.2913109064102173
# ts 79 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.38799968361854553                             0.5286237001419067 0.2892802953720093
# ts 80 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.3841792941093445                             0.5269334316253662 0.28763052821159363
# ts 81 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.3810877799987793                             0.5255562663078308 0.28629007935523987
# ts 82 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.3785839080810547                             0.5244346261024475 0.285200834274292
# ts 83 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.17589999735355377 0.3765546381473541                             0.5235214829444885 0.28431567549705505
# ts 84 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.14300000667572021 0.3687584698200226                             0.5199717283248901 0.28088876605033875
# ts 85 head_segment 4185243 segINDEX 1 segID 4186107                             FNL:ql qdc vel depth 0.14300000667572021 0.3577861189842224                             0.5148820877075195 0.27601391077041626
# ...
# ts 61 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.6580618619918823                             0.05662112683057785 1.8112268447875977
# ts 62 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.6491270065307617                             0.05642618611454964 1.799617052078247
# ts 63 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.6393296718597412                             0.05621091276407242 1.7868330478668213
# ts 64 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.628953218460083                             0.05598067119717598 1.773202657699585
# ts 65 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.6183830499649048                             0.055743660777807236 1.7592175006866455
# ts 66 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.6079579591751099                             0.05550743266940117 1.745324969291687
# ts 67 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5979262590408325                             0.055277787148952484 1.7318644523620605
# ts 68 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.588447630405426                             0.05505870282649994 1.7190643548965454
# ts 69 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5796092748641968                             0.05485255643725395 1.707056999206543
# ts 70 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5714452266693115                             0.05466052144765854 1.6959044933319092
# ts 71 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5639533996582031                             0.05448293685913086 1.6856188774108887
# ts 72 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5571083426475525                             0.054319534450769424 1.676177740097046
# ts 73 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5508712530136108                             0.054169654846191406 1.6675386428833008
# ts 74 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5441765785217285                             0.05400894582271576 1.6582963466644287
# ts 75 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5368483066558838                             0.05383194983005524 1.6481431722640991
# ts 76 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5290606021881104                             0.053642209619283676 1.6372886896133423
# ts 77 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5210800766944885                             0.05344589427113533 1.6260907649993896
# ts 78 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5131549835205078                             0.05324903503060341 1.6148958206176758
# ts 79 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.5054771900177002                             0.05305652320384979 1.6039801836013794
# ts 80 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4981772303581238                             0.05287184566259384 1.593538522720337
# ts 81 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4913329482078552                             0.05269721895456314 1.5836931467056274
# ts 82 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4849811792373657                             0.05253388360142708 1.5745086669921875
# ts 83 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4791296124458313                             0.05238232761621475 1.5660070180892944
# ts 84 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4737662374973297                             0.05224248021841049 1.558180332183838
# ts 85 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.46886688470840454                             0.052113961428403854 1.5510025024414062
# ts 86 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4636574387550354                             0.0519774854183197 1.5433963537216187
# ts 87 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4579832851886749                             0.0518280528485775 1.5350873470306396
# ts 88 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.45194968581199646                             0.05166788771748543 1.5262035131454468
# ts 89 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.44574227929115295                             0.05150165408849716 1.5170068740844727
# ts 90 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.43954381346702576                             0.05133415758609772 1.507765293121338
# ts 91 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.43350252509117126                             0.05116947740316391 1.4987034797668457
# ts 92 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.42772459983825684                             0.05101064220070839 1.489986538887024
# ts 93 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.422277569770813                             0.050859712064266205 1.481724500656128
# ts 94 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4171980023384094                             0.050717923790216446 1.4739810228347778
# ts 95 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4124988615512848                             0.05058585852384567 1.4667848348617554
# ts 96 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.40817683935165405                             0.05046361684799194 1.4601383209228516
# ts 97 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.40421760082244873                             0.050350986421108246 1.4540263414382935
# ts 98 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.4000479280948639                             0.05023255571722984 1.447611927986145
# ts 99 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3955349922180176                             0.05010378360748291 1.440651774406433
# ts 100 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.39074158668518066                             0.04996602237224579 1.4332224130630493
# ts 101 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.385797917842865                             0.04982277750968933 1.4255155324935913
# ts 102 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.38083982467651367                             0.049677908420562744 1.4177403450012207
# ts 103 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3759821653366089                             0.04953480139374733 1.4100786447525024
# ts 104 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3713110089302063                             0.0493960864841938 1.40267014503479
# ts 105 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.36688435077667236                             0.04926364868879318 1.395613431930542
# ts 106 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.362736314535141                             0.04913867637515068 1.3889689445495605
# ts 107 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3588825464248657                             0.04902181029319763 1.3827685117721558
# ts 108 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.35532498359680176                             0.048913273960351944 1.377021312713623
# ts 109 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.352056086063385                             0.04881298914551735 1.3717209100723267
# ts 110 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3486458361148834                             0.04870852455496788 1.3662095069885254
# ts 111 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3449818789958954                             0.048595838248729706 1.3602756261825562
# ts 112 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.34109991788864136                             0.04847566410899162 1.3539602756500244
# ts 113 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.33709174394607544                             0.048350632190704346 1.3474042415618896
# ts 114 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3330584764480591                             0.048223838210105896 1.3407702445983887
# ts 115 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.32908928394317627                             0.04809807240962982 1.3342053890228271
# ts 116 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.32525360584259033                             0.04797564074397087 1.327828288078308
# ts 117 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3216004967689514                             0.04785819724202156 1.32172429561615
# ts 118 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.31816092133522034                             0.04774687439203262 1.3159505128860474
# ts 119 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.31495118141174316                             0.047642335295677185 1.3105391263961792
# ts 120 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3119763135910034                             0.04754488542675972 1.3055039644241333
# ts 121 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3092333972454071                             0.047454558312892914 1.300844669342041
# ts 122 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3063952922821045                             0.04736122861504555 1.2960388660430908
# ts 123 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.30336785316467285                             0.0472613200545311 1.2909032106399536
# ts 124 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.3001701235771179                             0.04715514928102493 1.2854561805725098
# ts 125 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.29686737060546875                             0.04704471677541733 1.279801607131958
# ts 126 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2935355305671692                             0.046932484954595566 1.2740670442581177
# ts 127 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.29024410247802734                             0.04682080075144768 1.2683720588684082
# ts 128 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.287049263715744                             0.04671162739396095 1.2628166675567627
# ts 129 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.28399229049682617                             0.04660645127296448 1.2574752569198608
# ts 130 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.28110069036483765                             0.04650631919503212 1.2524000406265259
# ts 131 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.27839040756225586                             0.0464119017124176 1.2476232051849365
# ts 132 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.27586829662323                             0.04632354527711868 1.243160605430603
# ts 133 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2735343873500824                             0.04624135419726372 1.2390165328979492
# ts 134 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2711371183395386                             0.04615705460309982 1.2347724437713623
# ts 135 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2685980498790741                             0.04606747627258301 1.2302701473236084
# ts 136 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.26592594385147095                             0.04597267508506775 1.2255139350891113
# ts 137 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2631673812866211                             0.04587417095899582 1.2205806970596313
# ts 138 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2603797912597656                             0.04577392339706421 1.2155702114105225
# ts 139 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.25761765241622925                             0.045673903077840805 1.2105807065963745
# ts 140 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.25492626428604126                             0.045575786381959915 1.2056952714920044
# ts 141 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.2523402273654938                             0.045480888336896896 1.200979232788086
# ts 142 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.24988365173339844                             0.045390188694000244 1.1964796781539917
# ts 143 head_segment 2743396 segINDEX 0 segID 2743396                             FNL:ql qdc vel depth 0.0 0.24757151305675507                             0.045304324477910995 1.1922274827957153
