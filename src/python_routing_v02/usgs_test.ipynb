# %%
def get_ql_from_wrf_hydro(qlat_files, index_col="station_id", value_col="q_lateral"):
    """
    qlat_files: globbed list of CHRTOUT files containing desired lateral inflows
    index_col: column/field in the CHRTOUT files with the segment/link id
    value_col: column/field in the CHRTOUT files with the lateral inflow value

    In general the CHRTOUT files contain one value per time step. At present, there is
    no capability for handling non-uniform timesteps in the qlaterals.

    The qlateral may also be input using comma delimited file -- see
    `get_ql_from_csv`
    """

    li = []

    for filename in qlat_files:
        with xr.open_dataset(filename) as ds:
            df1 = ds.to_dataframe()

        li.append(df1)

    frame = pd.concat(li, axis=0, ignore_index=False)
    mod = frame.reset_index()
    ql = mod.pivot(index=index_col, columns="time", values=value_col)

    return ql

# %%
if qlat_input_folder:
        qlat_files = glob.glob(qlat_input_folder + qlat_file_pattern_filter)
        qlat_df = nio.get_ql_from_wrf_hydro(
            qlat_files=qlat_files,
            index_col=qlat_file_index_col,
            value_col=qlat_file_value_col,
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-ed632a13ba49> in <module>
# ----> 1 if qlat_input_folder:
#       2         qlat_files = glob.glob(qlat_input_folder + qlat_file_pattern_filter)
#       3         qlat_df = nio.get_ql_from_wrf_hydro(
#       4             qlat_files=qlat_files,
#       5             index_col=qlat_file_index_col,
#
# NameError: name 'qlat_input_folder' is not defined

# %%
root = pathlib.Path("/", "content", "t-route")

        test_folder = pathlib.Path(root, "test")
        geo_input_folder = test_folder.joinpath("input", "geo")

    
    
        forcing_parameters["qlat_input_folder"] = os.path.join(
                root,
                "test/input/geo/NWM_2.1_Sample_Datasets/Pocono_TEST1/example_CHRTOUT/",
            )
            forcing_parameters["qlat_file_pattern_filter"] = "/*.CHRTOUT_DOMAIN1"
# Out:
#   File "<ipython-input-66-d956eb4386d7>", line 3
#     test_folder = pathlib.Path(root, "test")
#     ^
# IndentationError: unexpected indent

# %%
import glob
import pathlib 
import os 
import pandas as pd

qlat_file_index_col = "feature_id"
qlat_file_value_col = "q_lateral"

root = pathlib.Path("/", "t-route_fresh", "t-route")
usgs_timeslices_folder = os.path.join(
        root,
        "test/input/geo/nudgingTimeSliceObs/",
    )

usgs_file_pattern_filter = "*.usgsTimeSlice.ncdf"

usgs_files = glob.glob(usgs_timeslices_folder + usgs_file_pattern_filter)

file_name = "2020-03-19_18:00:00.15min.usgsTimeSlice.ncdf"
usgs_timeslices_folder + file_name
# usgs_df = get_ql_from_wrf_hydro(
#     qlat_files=usgs_files,
#     index_col=qlat_file_index_col,
#     value_col=qlat_file_value_col,
# )
# Out:
# '/t-route_fresh/t-route/test/input/geo/nudgingTimeSliceObs/2020-03-19_18:00:00.15min.usgsTimeSlice.ncdf'

# %%
file_name = "2020-03-19_18:00:00.15min.usgsTimeSlice.ncdf"
usgs_timeslices_folder + file_name
# Out:
# '/t-route_fresh/t-route/test/input/geo/nudgingTimeSliceObs/2020-03-19_18:00:00.15min.usgsTimeSlice.ncdf'

# %%
import xarray as xr
usgs_files = glob.glob(usgs_timeslices_folder + file_name)
ds = xr.open_dataset("/home/jacob.hreha/github/troute/t-route/test/input/geo/nudgingTimeSliceObs/" + file_name)
df = ds.to_dataframe()
df['stationId'] = df['stationId'].str.decode('utf-8') 
df['time'] = df['time'].str.decode('utf-8') 

df
# df.reset_index()
# df.set_index('stationId')
# Out:
#                     stationId                 time      discharge  \
# stationIdInd
# 0                    08158930  2020-03-19_18:00:00 -999999.000000
# 1                    02336300  2020-03-19_18:00:00 -999999.000000
# 2                    08086212  2020-03-19_18:00:00 -999999.000000
# 3                    02215260  2020-03-19_18:00:00     252.019928
# 4                    02439400  2020-03-19_18:00:00      58.899040
# ...                       ...                  ...            ...
# 3864                 00000417  2020-03-19_18:00:00 -999999.000000
# 3865                 03353200  2020-03-19_18:00:00       9.202975
# 3866                 02303000  2020-03-19_18:00:00 -999999.000000
# 3867                 09386950  2020-03-19_18:00:00       0.000000
# 3868                 05374000  2020-03-19_18:00:00 -999999.000000
#
#               discharge_quality           queryTime
# stationIdInd
# 0                           100 2020-03-19 18:00:00
# 1                           100 2020-03-19 18:00:00
# 2                           100 2020-03-19 18:00:00
# 3                           100 2020-03-19 18:00:00
# 4                           100 2020-03-19 18:00:00
# ...                         ...                 ...
# 3864                        100 2020-03-19 18:00:00
# 3865                        100 2020-03-19 18:00:00
# 3866                        100 2020-03-19 18:00:00
# 3867                        100 2020-03-19 18:00:00
# 3868                        100 2020-03-19 18:00:00
#
# [3869 rows x 5 columns]

# %%
df
# Out:
#                     stationId                 time      discharge  \
# stationIdInd
# 0                    08158930  2020-03-19_18:00:00 -999999.000000
# 1                    02336300  2020-03-19_18:00:00 -999999.000000
# 2                    08086212  2020-03-19_18:00:00 -999999.000000
# 3                    02215260  2020-03-19_18:00:00     252.019928
# 4                    02439400  2020-03-19_18:00:00      58.899040
# ...                       ...                  ...            ...
# 3864                 00000417  2020-03-19_18:00:00 -999999.000000
# 3865                 03353200  2020-03-19_18:00:00       9.202975
# 3866                 02303000  2020-03-19_18:00:00 -999999.000000
# 3867                 09386950  2020-03-19_18:00:00       0.000000
# 3868                 05374000  2020-03-19_18:00:00 -999999.000000
#
#               discharge_quality           queryTime
# stationIdInd
# 0                           100 2020-03-19 18:00:00
# 1                           100 2020-03-19 18:00:00
# 2                           100 2020-03-19 18:00:00
# 3                           100 2020-03-19 18:00:00
# 4                           100 2020-03-19 18:00:00
# ...                         ...                 ...
# 3864                        100 2020-03-19 18:00:00
# 3865                        100 2020-03-19 18:00:00
# 3866                        100 2020-03-19 18:00:00
# 3867                        100 2020-03-19 18:00:00
# 3868                        100 2020-03-19 18:00:00
#
# [3869 rows x 5 columns]

# %%
def get_usgs_from_wrf_hydro(qlat_files,index_col="stationIdInd",value_col="discharge"):
    """
    qlat_files: globbed list of CHRTOUT files containing desired lateral inflows
    index_col: column/field in the CHRTOUT files with the segment/link id
    value_col: column/field in the CHRTOUT files with the lateral inflow value

    In general the CHRTOUT files contain one value per time step. At present, there is
    no capability for handling non-uniform timesteps in the qlaterals.

    The qlateral may also be input using comma delimited file -- see
    `get_ql_from_csv`
    """

    li = []

    for filename in qlat_files:
        with xr.open_dataset(filename) as ds:
            df1 = ds.to_dataframe()

        li.append(df1)

    frame = pd.concat(li, axis=0, ignore_index=False)
    mod = frame.reset_index()
    usgs_df = mod.pivot(index="stationIdInd", columns="time", values=[value_col])

    return usgs_df

# %%
# import glob, os
# os.chdir("/home/jacob.hreha/github/troute/t-route/test/input/geo/nudgingTimeSliceObs/")
# usgs_files = glob.glob(file_name)

# usgs_df = get_usgs_from_wrf_hydro(
#     qlat_files=usgs_files,
#     index_col="stationIdInd",
#     value_col="discharge",
# )
# usgs_df

# %%
# ../../test/input/geo/NWM_2.1_Sample_Datasets/Pocono_TEST1/primary_domain/DOMAIN/Route_Link.nc

# %%
import xarray as xr


usgs_files = glob.glob(usgs_timeslices_folder + file_name)
ds = xr.open_dataset("/home/jacob.hreha/github/troute/t-route/test/input/geo/nudgingTimeSliceObs/" + file_name)
df2 = ds.to_dataframe()
df2['stationId'] = df2['stationId'].str.decode('utf-8') 
df2['time'] = df2['time'].str.decode('utf-8') 

# df2.reset_index(drop=True)
# df2 = df2.reset_index(level='stationId')

df2 = df2.reset_index()
df2.drop(df2.columns.difference(['stationId','time','discharge','discharge_quality']), 1, inplace=True)
# df2 = df2['stationId'].astype(float)
# df2 = df2.set_index('stationId')
df2
df2.reset_index()
df2.set_index('stationId', inplace=True)
df2 = df2.reset_index()
df2.index = df2.index.set_names(['position'])
df2 = df2.reset_index()
df2 = df2.set_index(['stationId'])
df2

df2.loc['       08158930']
# Out:
# position                               0
# time                 2020-03-19_18:00:00
# discharge                        -999999
# discharge_quality                    100
# Name:        08158930, dtype: object

# %%
df2 = df2.reset_index()
df2.index = df2.index.set_names(['position'])
# df2 = df2.set_index(['link'])
df2
# Out:
#           position        stationId                 time      discharge  \
# position
# 0                0         08158930  2020-03-19_18:00:00 -999999.000000
# 1                1         02336300  2020-03-19_18:00:00 -999999.000000
# 2                2         08086212  2020-03-19_18:00:00 -999999.000000
# 3                3         02215260  2020-03-19_18:00:00     252.019928
# 4                4         02439400  2020-03-19_18:00:00      58.899040
# ...            ...              ...                  ...            ...
# 1860984    1860984         00000417  2020-03-24_18:00:00 -999999.000000
# 1860985    1860985         03353200  2020-03-24_18:00:00       6.258023
# 1860986    1860986         02303000  2020-03-24_18:00:00 -999999.000000
# 1860987    1860987         09386950  2020-03-24_18:00:00       0.000000
# 1860988    1860988         05374000  2020-03-24_18:00:00 -999999.000000
#
#           discharge_quality
# position
# 0                       100
# 1                       100
# 2                       100
# 3                       100
# 4                       100
# ...                     ...
# 1860984                 100
# 1860985                 100
# 1860986                 100
# 1860987                 100
# 1860988                 100
#
# [1860989 rows x 5 columns]

# %%
ds = xr.open_dataset("/home/APD/inland_hydraulics/wrf-hydro-run/DOMAIN/routeLink_subset.nc")
df3 = ds.to_dataframe()
df3.sort_values('link')
df3 = df3.reset_index()
df3.index = df3.index.set_names(['position'])
df3 = df3.set_index(['link'])
df3
# df.index = df.index.set_names(['foo'])
# Out:
#             feature_id  from          to         lon        lat         alt  \
# link
# 14828145             0     0    14828071  -96.919670  46.893719  273.290009
# 7069483              1     0     7069499  -96.710838  48.213661  266.420013
# 7069499              2     0     7069507  -96.730247  48.205956  264.959991
# 14172539             3     0    14172507 -100.526756  48.169743  460.619995
# 6689073              4     0     6689049  -96.628960  46.787830  278.519989
# ...                ...   ...         ...         ...        ...         ...
# 2788603         109218     0           0 -121.875320  38.047585    0.000000
# 1010002381      109219     0  1010002385  -67.818100  47.081886  127.989998
# 1010002385      109220     0  1010002388  -67.813759  47.078209  127.910004
# 1010002388      109221     0  1010002391  -67.802383  47.071709  126.000000
# 1010002391      109222     0           0  -67.790802  47.067303  128.009995
#
#             order   Qi    MusK  MusX  ...     ChSlp    BtmWdth  \
# link                                  ...
# 14828145        3  0.0  3600.0   0.2  ...  0.386170   7.358820
# 7069483         4  0.0  3600.0   0.2  ...  0.311776  11.952611
# 7069499         4  0.0  3600.0   0.2  ...  0.311169  12.005546
# 14172539        4  0.0  3600.0   0.2  ...  0.281200  15.103322
# 6689073         5  0.0  3600.0   0.2  ...  0.272118  16.270174
# ...           ...  ...     ...   ...  ...       ...        ...
# 2788603         7  0.0  3600.0   0.2  ...  0.159416  54.672470
# 1010002381      6  0.0  3600.0   0.2  ...  0.176434  43.443199
# 1010002385      6  0.0  3600.0   0.2  ...  0.176400  43.462093
# 1010002388      6  0.0  3600.0   0.2  ...  0.176375  43.476273
# 1010002391      6  0.0  3600.0   0.2  ...  0.176370  43.478970
#
#             NHDWaterbodyComID       time               gages  Kchan  \
# link
# 14828145                -9999 2000-01-01  b'       05059480'      0
# 7069483                 -9999 2000-01-01  b'       05085450'      0
# 7069499                 -9999 2000-01-01  b'               '      0
# 14172539                -9999 2000-01-01  b'       05120500'      0
# 6689073                 -9999 2000-01-01  b'       05061500'      0
# ...                       ...        ...                 ...    ...
# 2788603                 -9999 2000-01-01  b'               '      0
# 1010002381              -9999 2000-01-01  b'               '      0
# 1010002385              -9999 2000-01-01  b'               '      0
# 1010002388              -9999 2000-01-01  b'               '      0
# 1010002391              -9999 2000-01-01  b'               '      0
#
#            ascendingIndex   nCC   TopWdthCC    TopWdth
# link
# 14828145          2723024  0.11   36.794102  12.264701
# 7069483           1548739  0.11   59.763058  19.921019
# 7069499           1452123  0.11   60.027729  20.009243
# 14172539          1423703  0.11   75.516609  25.172203
# 6689073           1349895  0.10   81.350876  27.116957
# ...                   ...   ...         ...        ...
# 2788603           2656814  0.09  273.362335  91.120781
# 1010002381        2656735  0.10  217.215988  72.405334
# 1010002385        2656716  0.10  217.310471  72.436829
# 1010002388        2719210  0.10  217.381363  72.460457
# 1010002391        2656722  0.10  217.394852  72.464951
#
# [109223 rows x 23 columns]

# %%
ds = xr.open_dataset("/home/APD/inland_hydraulics/wrf-hydro-run/DOMAIN/RouteLink.nc")
df = ds.to_dataframe()
# df['stationId'] = df['stationId'].str.decode('utf-8') 
# df['time'] = df['time'].str.decode('utf-8') 

df
# df.reset_index()
# df.set_index('stationId')
# Out:
#                   link  from          to         lon        lat         alt  \
# feature_id
# 0             14828145     0    14828071  -96.919670  46.893719  273.290009
# 1              7069483     0     7069499  -96.710838  48.213661  266.420013
# 2              7069499     0     7069507  -96.730247  48.205956  264.959991
# 3             14172539     0    14172507 -100.526756  48.169743  460.619995
# 4              6689073     0     6689049  -96.628960  46.787830  278.519989
# ...                ...   ...         ...         ...        ...         ...
# 109218         2788603     0           0 -121.875320  38.047585    0.000000
# 109219      1010002381     0  1010002385  -67.818100  47.081886  127.989998
# 109220      1010002385     0  1010002388  -67.813759  47.078209  127.910004
# 109221      1010002388     0  1010002391  -67.802383  47.071709  126.000000
# 109222      1010002391     0           0  -67.790802  47.067303  128.009995
#
#             order   Qi    MusK  MusX  ...     ChSlp    BtmWdth  \
# feature_id                            ...
# 0               3  0.0  3600.0   0.2  ...  0.386170   7.358820
# 1               4  0.0  3600.0   0.2  ...  0.311776  11.952611
# 2               4  0.0  3600.0   0.2  ...  0.311169  12.005546
# 3               4  0.0  3600.0   0.2  ...  0.281200  15.103322
# 4               5  0.0  3600.0   0.2  ...  0.272118  16.270174
# ...           ...  ...     ...   ...  ...       ...        ...
# 109218          7  0.0  3600.0   0.2  ...  0.159416  54.672470
# 109219          6  0.0  3600.0   0.2  ...  0.176434  43.443199
# 109220          6  0.0  3600.0   0.2  ...  0.176400  43.462093
# 109221          6  0.0  3600.0   0.2  ...  0.176375  43.476273
# 109222          6  0.0  3600.0   0.2  ...  0.176370  43.478970
#
#             NHDWaterbodyComID       time               gages  Kchan  \
# feature_id
# 0                       -9999 2000-01-01  b'       05059480'      0
# 1                       -9999 2000-01-01  b'       05085450'      0
# 2                       -9999 2000-01-01  b'               '      0
# 3                       -9999 2000-01-01  b'       05120500'      0
# 4                       -9999 2000-01-01  b'       05061500'      0
# ...                       ...        ...                 ...    ...
# 109218                  -9999 2000-01-01  b'               '      0
# 109219                  -9999 2000-01-01  b'               '      0
# 109220                  -9999 2000-01-01  b'               '      0
# 109221                  -9999 2000-01-01  b'               '      0
# 109222                  -9999 2000-01-01  b'               '      0
#
#            ascendingIndex   nCC   TopWdthCC    TopWdth
# feature_id
# 0                 2723024  0.11   36.794102  12.264701
# 1                 1548739  0.11   59.763058  19.921019
# 2                 1452123  0.11   60.027729  20.009243
# 3                 1423703  0.11   75.516609  25.172203
# 4                 1349895  0.10   81.350876  27.116957
# ...                   ...   ...         ...        ...
# 109218            2656814  0.09  273.362335  91.120781
# 109219            2656735  0.10  217.215988  72.405334
# 109220            2656716  0.10  217.310471  72.436829
# 109221            2719210  0.10  217.381363  72.460457
# 109222            2656722  0.10  217.394852  72.464951
#
# [109223 rows x 23 columns]

# %%
import numpy as np
df = df.reset_index()
df.drop(df.columns.difference(['link','to','gages','ascendingIndex']), 1, inplace=True)

df['gages'] = df['gages'].str.decode('utf-8')
nan_value = float("NaN")
df['gages'].replace('               ', nan_value, inplace=True)
df = df[df['gages'].notna()]
df.dropna(subset=['gages'], inplace=True)

df = df.set_index('gages')


df
# Out:
#                      link        to  ascendingIndex
# gages
#        05059480  14828145  14828071         2723024
#        05085450   7069483   7069499         1548739
#        05120500  14172539  14172507         1423703
#        05061500   6689073   6689049         1349895
#        05085000  14434343  14434353         1350164
# ...                   ...       ...             ...
#        00000378   2851585   2851605         2718843
#        11390500   2851625   2852741         2719415
#        00000136   2858219   2858243         2656953
#        00000336  15039173  15039309         2719007
#        00000334  15048247  15048249         2656587
#
# [3477 rows x 3 columns]

# %%
# df.loc['       4185517']

# %%
df.loc[df['link']==4153018]
# Out:
# Empty DataFrame
# Columns: [link, to, ascendingIndex]
# Index: []

# %%
# mod1 = df2.join(df)
# mod1 = mod1.reset_index()
# mod2 = mod1.drop(mod1.columns.difference(['to','time','gages','discharge','discharge_quality']), 1, inplace=True)
mod2 = df2.join(df)
mod2 = mod2.reset_index()
mod2 = mod2[mod2['index'].notna()]
nan_value = float("NaN")
mod2['index'].replace(['               ','            N/A','           NONE'], nan_value, inplace=True)
mod2 = mod2[mod2['index'].notna()]
# pd.to_numeric(mod2['index']) 
mod2 = mod2.set_index(['index'])
mod2
# Out:
#                                 time      discharge  discharge_quality  \
# index
#            0922  2020-03-19_18:00:00       0.169901                100
#           00090  2020-03-19_18:00:00 -999999.000000                100
#         0635480  2020-03-19_18:00:00 -999999.000000                100
#         0811500  2020-03-19_18:00:00 -999999.000000                100
#         0818810  2020-03-19_18:00:00 -999999.000000                100
# ...                              ...            ...                ...
#      0818999010  2020-03-19_18:00:00 -999999.000000                100
#      2948311020  2020-03-19_18:00:00 -999999.000000                100
#      3010301044  2020-03-19_18:00:00 -999999.000000                100
# 390707081443202  2020-03-19_18:00:00 -999999.000000                100
# 411925089063901  2020-03-19_18:00:00     370.950684                100
#
#                          link            to  ascendingIndex
# index
#            0922  3.196672e+06  3.196618e+06        804014.0
#           00090  4.288013e+06  4.287793e+06       1449374.0
#         0635480  1.466539e+07  1.466510e+07       2183756.0
#         0811500  3.124238e+06  3.124256e+06        469878.0
#         0818810  1.643099e+06  1.643101e+06         46899.0
# ...                       ...           ...             ...
#      0818999010  7.869629e+06  7.869233e+06        592372.0
#      2948311020  1.131000e+09  1.131000e+09        637201.0
#      3010301044  1.131000e+09  1.131000e+09       1246096.0
# 390707081443202  1.944043e+07  1.944044e+07        508198.0
# 411925089063901  1.483769e+07  1.483770e+07       1210187.0
#
# [3474 rows x 6 columns]

# %%
mod2.loc[mod2['link']==14172539]
# Out:
#                                 time  discharge  discharge_quality  \
# index
#        05120500  2020-03-19_18:00:00  -999999.0                100
#
#                        link          to  ascendingIndex
# index
#        05120500  14172539.0  14172507.0       1423703.0

# %%
df2
# Out:
#                                 time      discharge  discharge_quality
# stationId
#        08158930  2020-03-19_18:00:00 -999999.000000                100
#        02336300  2020-03-19_18:00:00 -999999.000000                100
#        08086212  2020-03-19_18:00:00 -999999.000000                100
#        02215260  2020-03-19_18:00:00     252.019928                100
#        02439400  2020-03-19_18:00:00      58.899040                100
# ...                              ...            ...                ...
#        00000417  2020-03-19_18:00:00 -999999.000000                100
#        03353200  2020-03-19_18:00:00       9.202975                100
#        02303000  2020-03-19_18:00:00 -999999.000000                100
#        09386950  2020-03-19_18:00:00       0.000000                100
#        05374000  2020-03-19_18:00:00 -999999.000000                100
#
# [3869 rows x 3 columns]

# %%
import glob
import pathlib 
import os 
import pandas as pd
import xarray as xr

# qlat_file_index_col = "feature_id"
# qlat_file_value_col = "q_lateral"

root = pathlib.Path("/", "t-route_fresh", "t-route")
usgs_timeslices_folder = os.path.join(
        root,
        "test/input/geo/nudgingTimeSliceObs/",
    )

usgs_file_pattern_filter = "*.usgsTimeSlice.ncdf"

usgs_files = glob.glob(usgs_timeslices_folder + usgs_file_pattern_filter)

file_name = "2020-03-19_18:00:00.15min.usgsTimeSlice.ncdf"
usgs_timeslices_folder + file_name
# Out:
# '/t-route_fresh/t-route/test/input/geo/nudgingTimeSliceObs/2020-03-19_18:00:00.15min.usgsTimeSlice.ncdf'

# %%
ds = xr.open_dataset("/home/APD/inland_hydraulics/wrf-hydro-run/DOMAIN/RouteLink.nc")
df = ds.to_dataframe()
df = df.reset_index()
df.drop(df.columns.difference(['link','to','gages','ascendingIndex']), 1, inplace=True)
df['gages'] = df['gages'].str.decode('utf-8')
nan_value = float("NaN")
df['gages'].replace('               ', nan_value, inplace=True)
df = df[df['gages'].notna()]
df.dropna(subset=['gages'], inplace=True)
df = df.set_index('gages')
df

/home/APD/inland_hydraulics/wrf-hydro-run/DOMAIN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-d8d0198840de> in <module>
#      11 df
#      12
# ---> 13 home/APD/inland_hydraulics/wrf-hydro-run/DOMAIN()
#
# NameError: name 'home' is not defined

# %%
ds = xr.open_mfdataset("/home/jacob.hreha/github/troute/t-route/test/input/geo/nudgingTimeSliceObs/*",combine='nested',concat_dim='stationIdInd')

# %%
ds['stationId'].values
# Out:
# array([b'       08158930', b'       02336300', b'       08086212', ...,
#        b'       02303000', b'       09386950', b'       05374000'],
#       dtype='|S15')

# %%
# usgs_files = glob.glob(usgs_timeslices_folder + file_name)
# ds = xr.open_dataset("/home/jacob.hreha/github/troute/t-route/test/input/geo/nudgingTimeSliceObs/" + file_name)
ds = xr.open_mfdataset("/home/jacob.hreha/github/troute/t-route/test/input/geo/nudgingTimeSliceObs/*",combine='nested',concat_dim='stationIdInd')
df2 = ds.to_dataframe()
df2['stationId'] = df2['stationId'].str.decode('utf-8') 
df2['time'] = df2['time'].str.decode('utf-8') 
df2 = df2.reset_index()
df2.drop(df2.columns.difference(['stationId','time','discharge','discharge_quality']), 1, inplace=True)
df2.reset_index()
df2.set_index('stationId', inplace=True)

df2
# ql = mod.pivot(index=index_col, columns="time", values=value_col)
# Out:
#                                 time      discharge  discharge_quality
# stationId
#        08158930  2020-03-19_18:00:00 -999999.000000                100
#        02336300  2020-03-19_18:00:00 -999999.000000                100
#        08086212  2020-03-19_18:00:00 -999999.000000                100
#        02215260  2020-03-19_18:00:00     252.019928                100
#        02439400  2020-03-19_18:00:00      58.899040                100
# ...                              ...            ...                ...
#        00000417  2020-03-24_18:00:00 -999999.000000                100
#        03353200  2020-03-24_18:00:00       6.258023                100
#        02303000  2020-03-24_18:00:00 -999999.000000                100
#        09386950  2020-03-24_18:00:00       0.000000                100
#        05374000  2020-03-24_18:00:00 -999999.000000                100
#
# [1860989 rows x 3 columns]

# %%
# df_temp.duplicated()

# %%
# df2.iloc[3923]

# %%
# df.insert(4, 'new_col_name', tmp)

# %%
# columns_list = (df_temp.columns)
# columns_list

# %%
# df_temp['2020-03-19_18:00:00']

# %%
# df_temp.columns[0]
# temp = df_temp.columns[0]
# temp2 = temp[:-5]
# temp3 = temp2 + str('05:00')
# temp4 = temp2 + str('10:00')
# temp3,temp4

# %%
# df.insert(4, 'new_col_name', tmp)

# %%
# df_temp

# %%
df_temp = df2
# df_temp = df_temp.pivot(index='stationId', columns="time", values="discharge")
df_temp = df_temp.pivot_table(values='discharge', index=df_temp.index, columns='time', aggfunc='first')
# df_temp.pivot(index='stationId', columns='time', values='discharge')
# df_temp.pivot_table(df_temp, values ='discharge', index=['stationId'], columns = 'time').reset_index()
# ql = mod.pivot(index=index_col, columns="time", values=value_col)

df_temp
# Out:
# time             2020-03-19_18:00:00  2020-03-19_18:15:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           370.950684           371.894592
#
# time             2020-03-19_18:30:00  2020-03-19_18:45:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           372.838470           373.782379
#
# time             2020-03-19_19:00:00  2020-03-19_19:15:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           374.726257           375.670166
#
# time             2020-03-19_19:30:00  2020-03-19_19:45:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           376.614044           377.557953
#
# time             2020-03-19_20:00:00  2020-03-19_20:15:00  ...  \
# stationId                                                  ...
#                            11.128521            11.128521  ...
#             N/A       -999999.000000       -999999.000000  ...
#            0922             0.169901             0.169901  ...
#            NONE             0.226535             0.226535  ...
#           00090       -999999.000000       -999999.000000  ...
# ...                              ...                  ...  ...
#      0818999010       -999999.000000       -999999.000000  ...
#      2948311020       -999999.000000       -999999.000000  ...
#      3010301044       -999999.000000       -999999.000000  ...
# 390707081443202       -999999.000000       -999999.000000  ...
# 411925089063901           378.501831           379.445740  ...
#
# time             2020-03-24_15:45:00  2020-03-24_16:00:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           684.559814           683.379944
#
# time             2020-03-24_16:15:00  2020-03-24_16:30:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           682.200073           681.020203
#
# time             2020-03-24_16:45:00  2020-03-24_17:00:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           679.840332           678.660461
#
# time             2020-03-24_17:15:00  2020-03-24_17:30:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           677.480591           676.300720
#
# time             2020-03-24_17:45:00  2020-03-24_18:00:00
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           675.120850           673.940979
#
# [3476 rows x 481 columns]

# %%
columns_list = (df_temp.columns)

for i in range(0,(len(columns_list)*3)-12,12):
    original_string = df_temp.columns[i]
    original_string_shortened = original_string[:-5]
    temp_name1 = original_string_shortened + str('05:00')
    temp_name2 = original_string_shortened + str('10:00')
    temp_name3 = original_string_shortened + str('20:00')
    temp_name4 = original_string_shortened + str('25:00')
    temp_name5 = original_string_shortened + str('35:00')
    temp_name6 = original_string_shortened + str('40:00')
    temp_name7 = original_string_shortened + str('50:00')
    temp_name8 = original_string_shortened + str('55:00')
    df_temp.insert(i+1, temp_name1, np.nan)
    df_temp.insert(i+2, temp_name2, np.nan)
    df_temp.insert(i+4, temp_name3, np.nan)
    df_temp.insert(i+5, temp_name4, np.nan)
    df_temp.insert(i+7, temp_name5, np.nan)
    df_temp.insert(i+8, temp_name6, np.nan)
    df_temp.insert(i+10, temp_name7, np.nan)
    df_temp.insert(i+11, temp_name8, np.nan)
df_temp = df_temp.interpolate(method='linear',  axis=1)

# %%
df_temp = df_temp.interpolate(method='linear',  axis=1)

# %%
df_temp
# Out:
# time             2020-03-19_18:00:00  2020-03-19_18:05:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           370.950684           371.265320
#
# time             2020-03-19_18:10:00  2020-03-19_18:15:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           371.579956           371.894592
#
# time             2020-03-19_18:20:00  2020-03-19_18:25:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           372.209218           372.523844
#
# time             2020-03-19_18:30:00  2020-03-19_18:35:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           372.838470           373.153107
#
# time             2020-03-19_18:40:00  2020-03-19_18:45:00  ...  \
# stationId                                                  ...
#                            11.128521            11.128521  ...
#             N/A       -999999.000000       -999999.000000  ...
#            0922             0.169901             0.169901  ...
#            NONE             0.226535             0.226535  ...
#           00090       -999999.000000       -999999.000000  ...
# ...                              ...                  ...  ...
#      0818999010       -999999.000000       -999999.000000  ...
#      2948311020       -999999.000000       -999999.000000  ...
#      3010301044       -999999.000000       -999999.000000  ...
# 390707081443202       -999999.000000       -999999.000000  ...
# 411925089063901           373.467743           373.782379  ...
#
# time             2020-03-24_17:15:00  2020-03-24_17:20:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           677.480591           677.087301
#
# time             2020-03-24_17:25:00  2020-03-24_17:30:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           676.694010           676.300720
#
# time             2020-03-24_17:35:00  2020-03-24_17:40:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           675.907430           675.514140
#
# time             2020-03-24_17:45:00  2020-03-24_17:50:00  \
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           675.120850           674.727559
#
# time             2020-03-24_17:55:00  2020-03-24_18:00:00
# stationId
#                            11.128521            11.128521
#             N/A       -999999.000000       -999999.000000
#            0922             0.169901             0.169901
#            NONE             0.226535             0.226535
#           00090       -999999.000000       -999999.000000
# ...                              ...                  ...
#      0818999010       -999999.000000       -999999.000000
#      2948311020       -999999.000000       -999999.000000
#      3010301044       -999999.000000       -999999.000000
# 390707081443202       -999999.000000       -999999.000000
# 411925089063901           674.334269           673.940979
#
# [3476 rows x 1441 columns]

# %%
df_temp[4153018]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4153018
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-4bb2ae9cc6b0> in <module>
# ----> 1 df_temp[4153018]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4153018

# %%
mod2 = df2.join(df)
mod2 = mod2.reset_index()
mod2 = mod2[mod2['index'].notna()]
nan_value = float("NaN")
# mod2['index'].replace(['               '], nan_value, inplace=True)
mod2['index'].replace(['               ','            N/A','           NONE'], nan_value, inplace=True)
mod2 = mod2[mod2['index'].notna()]

# pd.to_numeric(mod2['index']) 
mod2 = mod2.set_index('index')
mod2

# %%
#remove discharge -999999
