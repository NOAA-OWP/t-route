# %%
## Basic imports
import sys
import os
import time

# WARNING: These global declarations cause the parallel implementation to 
# crash when executed on Windows
connections = None
networks = None
flowdepthvel = None

from sys import platform
if platform == "linux" or platform == "linux2":
    pass
elif platform == "darwin":
    pass
elif platform == "win32":
    print('The parallel version of compute_nhd_routing.py will not execute as currently')
    print('written due to the lack of a fork() capability in the windows OS.')
    print('For parallel execution, please us a *nix OS.')
    print('\nexiting...')
    sys.exit()
    # Some useful references:
    # https://stackoverflow.com/questions/985281/what-is-the-closest-thing-windows-has-to-fork/985525#985525
    # https://stackoverflow.com/questions/8220108/how-do-i-check-the-operating-system-in-python
    # https://stackoverflow.com/questions/6596617/python-multiprocess-diff-between-windows-and-linux

ENV_IS_CL = False
if ENV_IS_CL: root = '/content/wrf_hydro_nwm_public/trunk/NDHMS/dynamic_channel_routing/'
elif not ENV_IS_CL: 
    sys.setrecursionlimit(4000)
#     root = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
    root = os.path.dirname(os.path.dirname(os.path.abspath('')))
    sys.path.append(os.path.join(root, r'src', r'python_framework'))
    sys.path.append(os.path.join(root, r'src', r'python_routing')) #by Dong Ha
    fortran_source_dir = os.path.join(root, r'src', r'fortran_routing', r'mc_pylink_v00', r'MC_singleSeg_singleTS')
    sys.path.append(fortran_source_dir)
    
## F2PY Muskingum Cunge module
mc_f2py= True
if mc_f2py:
    try:
        import subprocess

        f2py_call = []
        f2py_call.append(r'f2py3')
        f2py_call.append(r'-c')
        f2py_call.append(r'varSingleSegStime_f2py_noIC_clean.f90')
        f2py_call.append(r'MCsingleSegStime_f2py_noIC_clean.f90')
        f2py_call.append(r'-m')
        f2py_call.append(r'mc_sseg_stime_noIC')
        subprocess.run(f2py_call, cwd=r'../fortran_routing/mc_pylink_v00/MC_singleSeg_singleTS',
                       stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    except Exception as e:
        print(e)
        
## network and reach utilities
import nhd_network_utilities as nnu
import nhd_reach_utilities as nru
import channel_routing_tools as crt

## Muskingum Cunge
import numpy as np

# def compute_network(
def mc_route_network(
          terminal_segment = None
        , network = None
        , supernetwork_data = None
        , nts = None
        , dt_mc= None
        , latflow= None
#         , connections = None
        , verbose = False
        , debuglevel = 0
        ):

    global connections
    global flowdepthvel 

    if verbose: print(f"Executing simulation on network {terminal_segment} beginning with streams of order {network['maximum_reach_seqorder']}")

    ##------------------------------------------------------------------------
    ## Compute ordered_reaches and last_segment_reach for all the segments of
    ## reach referenced by head_segment
    ##------------------------------------------------------------------------
    ordered_reaches = {}
    # Start: By Dong Ha
    last_segment_reach={}
    #End    
    for head_segment, reach in network['reaches'].items():
        if reach['seqorder'] not in ordered_reaches:
            ordered_reaches.update({reach['seqorder']:[]}) #TODO: Should this be a set/dictionary?
        ordered_reaches[reach['seqorder']].append([head_segment, reach])
        # Start: By Dong Ha
        seg_list=list(reach['segments_list'])
        lastseg=seg_list[0]
        last_segment_reach[head_segment]= lastseg
        # End 

    ##-------------------------------------------
    ## From jorder= maximum_reach_order to zero
    ##     From each reach that has jorder
    ##         run mc routing of a chosen scheme
    ##
    ## Output-> flowdepthvel
    ##--------------------------------------------
    #Note that not networks but network that takes networks values corresponding to 'terminal_segment' keys.
    #Also, network here takes 'terminal_segment' key only at the lower end of a network.      
    for x in range(network['maximum_reach_seqorder'],-1,-1):    
        
        for head_segment, reach in ordered_reaches[x]:       
            
            ## START: run MC over each segment over entire timesteps
            crt.mc_tlp_over_seg(
                            connections= connections 
                            ,supernetwork_data= supernetwork_data
                            ,reach= reach
                            ,last_segment_reach= last_segment_reach
                            ,nts= nts
                            ,dt_mc= dt_mc
                            ,latflow= None
                            ,flowdepthvel= flowdepthvel
                            )            
            ## END: MC-computed results for flow, vel, and depth are stored in 'flowdepthvel'
           
            ## Start: Only for printing results
            seg_list=list(reach['segments_list'])
            seg_list=seg_list[::-1] #to reversed order
            ncomp= len(reach['segments_list'])
            for seg in range(0,ncomp):  
                segID= seg_list[seg]
                for ts in range (0,nts):
                    print(f"ts {ts} head_segment {head_segment} segINDEX {seg} segID {segID} \
                            FNL:qdc vel depth {flowdepthvel[segID]['flow'][ts]} \
                            {flowdepthvel[segID]['vel'][ts]} {flowdepthvel[segID]['depth'][ts]}")  
            ## End
                          
def main():

    global connections
    global networks
    global flowdepthvel

    verbose = True
    debuglevel = 0
    showtiming = True

    test_folder = os.path.join(root, r'test')
    geo_input_folder = os.path.join(test_folder, r'input', r'geo', r'Channels')

    #TODO: Make these commandline args
    supernetwork= 'Pocono_TEST1'
    """##NHD Subset (Brazos/Lower Colorado)"""
#     supernetwork = 'Brazos_LowerColorado_ge5'
    """##NHD CONUS order 5 and greater"""
    # supernetwork = 'CONUS_ge5'
    """These are large -- be careful"""                          
#     supernetwork = 'Mainstems_CONUS'
    # supernetwork = 'CONUS_FULL_RES_v20'
    # supernetwork = 'CONUS_Named_Streams' #create a subset of the full resolution by reading the GNIS field
    # supernetwork = 'CONUS_Named_combined' #process the Named streams through the Full-Res paths to join the many hanging reaches

    if verbose: print('creating supernetwork connections set')
    if showtiming: start_time = time.time()
    #STEP 1
    supernetwork_data, supernetwork_values = nnu.set_networks(
        supernetwork = supernetwork
        , geo_input_folder = geo_input_folder
        , verbose = False
        # , verbose = verbose
        , debuglevel = debuglevel
        )
    if verbose: print('supernetwork connections set complete')
    if showtiming: print("... in %s seconds." % (time.time() - start_time))

    #STEP 2
    if showtiming: start_time = time.time()
    if verbose: print('organizing connections into networks and reaches ...')
    networks = nru.compose_reaches(
        supernetwork_values
        , verbose = False
        # , verbose = verbose
        , debuglevel = debuglevel
        , showtiming = showtiming
        )
    if verbose: print('reach organization complete')
    if showtiming: print("... in %s seconds." % (time.time() - start_time))
    

    #STEP 3: Route NHD streamflow
    if showtiming: start_time = time.time()
    executiontype = 'serial' # 'parallel'

    if verbose: print('executing serial computation on ordered reaches ...')
    connections = supernetwork_values[0]

    nts = 10  # number fof timestep = 1140 * 60(model timestep) = 86400 = day
    dt_mc= 300.0 # time interval for MC
    
    flowdepthvel = {connection:{'flow':np.zeros(nts)
                                , 'depth':np.zeros(nts)
                                , 'vel':np.zeros(nts)
                                , 'qlat':np.zeros(nts)}
                               for connection in connections}  

    if executiontype == 'serial':
        iter=0
        for terminal_segment, network in networks.items():
            if showtiming: network_start_time = time.time()
            iter=iter+1
            print(f"terminal_segment iter-> {iter}")
#             compute_network(
#                 terminal_segment = terminal_segment
#                 , network = network
#                 , supernetwork_data = supernetwork_data
#                 , nts = nts #number_of_time_steps
# #                 , connections = connections
#                 , verbose = False
#                 , debuglevel = debuglevel
#             )
            ## run MC to route network 
            mc_route_network(
                  terminal_segment = terminal_segment
                , network = network
                , supernetwork_data = supernetwork_data
                , nts = nts
                , dt_mc= dt_mc
                , latflow= None 
#         , connections = None
                , verbose = False
                , debuglevel = 0
            )
            
            if verbose: print(f'{terminal_segment} completed')
            if showtiming: print("... in %s seconds." % (time.time() - network_start_time))
        
    if verbose: print('ordered reach computation complete')
    if showtiming: print("... in %s seconds." % (time.time() - start_time))

if __name__ == '__main__':
    main()
# Out:
# creating supernetwork connections set
# supernetwork connections set complete
# ... in 0.03536248207092285 seconds.
# organizing connections into networks and reaches ...
# reach organization complete
# ... in 0.00015854835510253906 seconds.
# executing serial computation on ordered reaches ...
# terminal_segment iter-> 1
# ts 0 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 2.446152925491333                             0.21921786665916443 0.012610617093741894
# ts 1 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 6.932272911071777                             0.35855796933174133 0.026772120967507362
# ts 2 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 10.783014297485352                             0.504900336265564 0.04560691863298416
# ts 3 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 13.348472595214844                             0.6648293733596802 0.07065720111131668
# ts 4 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 14.57569694519043                             0.8418319225311279 0.10397408157587051
# ts 5 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 14.79707145690918                             2.747234582901001 1.2203145027160645
# ts 6 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 14.206028938293457                             3.2566585540771484 2.158454656600952
# ts 7 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 13.2096529006958                             3.2102317810058594 2.0488438606262207
# ts 8 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 11.81250286102295                             3.1387319564819336 1.890689730644226
# ts 9 head_segment 4153018 segINDEX 0 segID 4153018                             FNL:qdc vel depth 10.014286994934082                             3.0329627990722656 1.6789302825927734
# 4153018 completed
# ... in 0.0021376609802246094 seconds.
# terminal_segment iter-> 2
# ts 0 head_segment 4153786 segINDEX 0 segID 4153786                             FNL:qdc vel depth 0.13227979838848114                             0.0024269584100693464 0.010113355703651905
# ts 1 head_segment 4153786 segINDEX 0 segID 4153786                             FNL:qdc vel depth 0.3814501166343689                             0.004168787505477667 0.023450762033462524
# ts 2 head_segment 4153786 segINDEX 0 segID 4153786                             FNL:qdc vel depth 0.7481285333633423                             0.005918333772569895 0.041189514100551605
# ts 0 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 3.198223352432251                             0.09007413685321808 0.013714508153498173
# ts 1 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 11.835752487182617                             0.14491505920886993 0.028240296989679337
# ts 2 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 26.36355972290039                             0.20351189374923706 0.047559596598148346
# ts 3 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 45.0372200012207                             0.26862677931785583 0.07325426489114761
# ts 4 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 63.65513610839844                             0.3420819640159607 0.1074281707406044
# ts 5 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 79.10679626464844                             2.2078258991241455 10.775737762451172
# ts 6 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 92.20317077636719                             2.215625524520874 10.960938453674316
# ts 7 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 105.6378402709961                             2.2609519958496094 12.077169418334961
# ts 8 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 113.96525573730469                             2.41813325881958 16.421010971069336
# ts 9 head_segment 4186255 segINDEX 0 segID 4186255                             FNL:qdc vel depth 120.04985809326172                             1.856817364692688 4.701982498168945
# ts 0 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 3.737215995788574                             0.13794688880443573 0.012066470459103584
# ts 1 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 11.190793991088867                             0.22910289466381073 0.026048405095934868
# ts 2 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 21.080387115478516                             0.3256528079509735 0.04464437812566757
# ts 3 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 35.94517517089844                             0.4326169192790985 0.06937702745199203
# ts 4 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 55.98858642578125                             0.5531820058822632 0.10227144509553909
# ts 5 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 78.03497314453125                             0.6897780895233154 0.1460210382938385
# ts 6 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 98.5574951171875                             2.317216396331787 1.633880615234375
# ts 7 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 113.18721008300781                             3.540400505065918 8.687304496765137
# ts 8 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 125.45508575439453                             3.5947916507720947 9.367525100708008
# ts 9 head_segment 4186255 segINDEX 1 segID 4185607                             FNL:qdc vel depth 132.74964904785156                             3.6249947547912598 9.76236629486084
# ts 0 head_segment 4186255 segINDEX 2 segID 4186257                             FNL:qdc vel depth 9.340715408325195                             0.10622677206993103 0.014157287776470184
# ts 1 head_segment 4186255 segINDEX 2 segID 4186257                             FNL:qdc vel depth 23.480133056640625                             0.16964571177959442 0.028829192742705345
# ts 7 head_segment 4185649 segINDEX 0 segID 4185649                             FNL:qdc vel depth 12.926368713378906                             1.618568778038025 2.9018423557281494
# ts 8 head_segment 4185649 segINDEX 0 segID 4185649                             FNL:qdc vel depth 12.10136890411377                             1.5982201099395752 2.763739585876465
# ts 9 head_segment 4185649 segINDEX 0 segID 4185649                             FNL:qdc vel depth 10.57009220123291                             1.556056261062622 2.50002121925354
# ts 0 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 0.4702814221382141                             0.04279547557234764 0.010219898074865341
# ts 1 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 1.418829321861267                             0.074310801923275 0.02359246462583542
# ts 2 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 2.7531659603118896                             0.10723669081926346 0.04137797653675079
# ts 3 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 4.594077110290527                             0.14349301159381866 0.0650327131152153
# ts 4 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 6.957213401794434                             0.18420657515525818 0.09649351239204407
# ts 5 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 9.799653053283691                             0.23020270466804504 0.13833637535572052
# ts 6 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 16.20391082763672                             0.7051582932472229 1.2169456481933594
# ts 7 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 22.72939682006836                             1.1104363203048706 6.183842658996582
# ts 8 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 26.886856079101562                             1.1397039890289307 6.99661111831665
# ts 9 head_segment 4185649 segINDEX 1 segID 932040253                             FNL:qdc vel depth 28.708192825317383                             1.1511844396591187 7.339715957641602
# ts 0 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 0.7583940029144287                             0.02475052885711193 0.010244074277579784
# ts 1 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 2.1253278255462646                             0.04295702651143074 0.023624619469046593
# ts 2 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 4.105700492858887                             0.06199285015463829 0.041420742869377136
# ts 3 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 6.711353302001953                             0.08297105133533478 0.06508959084749222
# ts 4 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 9.941225051879883                             0.10655122250318527 0.09656915813684464
# ts 5 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 13.765495300292969                             0.13322313129901886 0.13843698799610138
# ts 6 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 18.1109561920166                             0.16334465146064758 0.19412121176719666
# ts 7 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 29.30963897705078                             0.6048111915588379 4.449850082397461
# ts 8 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 39.98590087890625                             0.7647982835769653 13.455785751342773
# ts 9 head_segment 4185649 segINDEX 2 segID 932040251                             FNL:qdc vel depth 47.006160736083984                             0.7469936609268188 12.07529067993164
# ts 0 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 0.8590133190155029                             0.0024695780593901873 0.010209798812866211
# ts 1 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 2.4015250205993652                             0.00429031066596508 0.023579033091664314
# ts 2 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 4.642983913421631                             0.006193523295223713 0.04136011749505997
# ts 3 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 7.62347412109375                             0.008290799334645271 0.06500896066427231
# ts 4 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 11.372411727905273                             0.010648202151060104 0.09646192193031311
# ts 5 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 15.892733573913574                             0.01331479661166668 0.13829436898231506
# ts 6 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 21.14551544189453                             0.01632646843791008 0.19393151998519897
# ts 7 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 53.277870178222656                             0.1141078993678093 53.45560073852539
# ts 8 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 67.54328918457031                             0.11968625336885452 60.42592239379883
# ts 9 head_segment 4185649 segINDEX 3 segID 932040249                             FNL:qdc vel depth 77.49737548828125                             0.12481902539730072 67.00917053222656
# ts 0 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 4.583790302276611                             0.04486072435975075 0.010970511473715305
# ts 1 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 12.209796905517578                             0.07639533281326294 0.024590780958533287
# ts 2 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 21.664640426635742                             0.10954460501670837 0.04270573705434799
# ts 3 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 31.977184295654297                             0.14615163207054138 0.066798634827137
# ts 4 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 42.23670959472656                             0.1873389035463333 0.09884218871593475
# ts 5 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 51.767181396484375                             0.23394708335399628 0.141460120677948
# ts 6 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 60.240455627441406                             0.286590039730072 0.19814197719097137
# ts 7 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 71.52450561523438                             1.0428974628448486 4.289974212646484
# ts 8 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 98.36719512939453                             1.4144428968429565 17.703086853027344
# ts 9 head_segment 4185649 segINDEX 4 segID 4186503                             FNL:qdc vel depth 113.70806884765625                             1.4280989170074463 18.425859451293945
# ts 0 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 1.1767346858978271                             0.03489922359585762 0.010193919762969017
# ts 1 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 3.386798858642578                             0.06067865714430809 0.023557912558317184
# ts 2 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 6.846681118011475                             0.08765164017677307 0.04133202135562897
# ts 3 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 11.83265495300293                             0.11741499602794647 0.06497158855199814
# ts 4 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 18.579036712646484                             0.15092907845973969 0.09641221165657043
# ts 5 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 27.189592361450195                             0.18892456591129303 0.13822825253009796
# ts 6 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 37.56804656982422                             0.23195913434028625 0.19384358823299408
# ts 7 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 63.41318130493164                             0.8663846850395203 4.175624847412109
# ts 8 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 87.498291015625                             1.195693850517273 19.2142276763916
# ts 9 head_segment 4185649 segINDEX 5 segID 4185693                             FNL:qdc vel depth 114.25836944580078                             1.2155414819717407 20.60892105102539
# ts 0 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 3.702022075653076                             0.03568881377577782 0.01054345816373825
# ts 1 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 10.052774429321289                             0.06146807223558426 0.024022798985242844
# ts 2 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 18.587833404541016                             0.08851474523544312 0.041950322687625885
# ts 3 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 28.971473693847656                             0.11839205771684647 0.06579393148422241
# ts 4 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 40.851200103759766                             0.1520538628101349 0.09750592708587646
# ts 5 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 53.89852523803711                             0.19023016095161438 0.13968288898468018
# ts 6 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 67.83888244628906                             0.2334793359041214 0.1957782506942749
# ts 7 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 96.50141906738281                             0.8998390436172485 4.853614807128906
# ts 8 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 127.4708251953125                             1.2305448055267334 21.50179100036621
# ts 9 head_segment 4185649 segINDEX 6 segID 4186297                             FNL:qdc vel depth 151.4927978515625                             1.2453296184539795 22.588294982910156
# ts 0 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 0.04545535892248154                             0.002443402772769332 0.01003859844058752
# ts 1 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 0.13980340957641602                             0.004268414806574583 0.023351335898041725
# ts 2 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 0.3049808442592621                             0.006177506875246763 0.0410572774708271
# ts 3 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 0.5740497708320618                             0.008285877294838428 0.0646061822772026
# ts 4 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 1.0019652843475342                             0.01066342368721962 0.09592622518539429
# ts 5 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 1.669805645942688                             0.013364404439926147 0.13758188486099243
# ts 6 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 2.6925129890441895                             0.016431771218776703 0.19298392534255981
# ts 7 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 6.512265205383301                             0.0596533864736557 3.3744964599609375
# ts 8 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 18.01544761657715                             0.09325264394283295 27.031705856323242
# ts 9 head_segment 4185665 segINDEX 0 segID 4185665                             FNL:qdc vel depth 50.37773895263672                             0.108094222843647 45.81665802001953
# ts 0 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 1.0446555614471436                             0.035608965903520584 0.010502702556550503
# ts 1 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 2.8999478816986084                             0.06142217293381691 0.023968596011400223
# ts 2 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 5.426202774047852                             0.088528573513031 0.04187823086977005
# ts 3 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 8.455204963684082                             0.11851472407579422 0.0656980499625206
# ts 4 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 11.749994277954102                             0.15236465632915497 0.09737841039896011
# ts 5 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 15.032308578491211                             0.19085094332695007 0.139513298869133
# ts 6 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 20.753028869628906                             0.5953602194786072 1.1635169982910156
# ts 7 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 24.184478759765625                             0.9839494228363037 6.307039260864258
# ts 8 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 26.962736129760742                             1.001208782196045 6.866703510284424
# ts 9 head_segment 4185665 segINDEX 1 segID 4186287                             FNL:qdc vel depth 34.55366897583008                             1.0397329330444336 8.306286811828613
# ts 0 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 0.020421519875526428                             0.0024417932145297527 0.010017246007919312
# ts 1 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 0.07459928095340729                             0.0042724222876131535 0.0233229361474514
# ts 2 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 0.19275885820388794                             0.006192536558955908 0.041019506752491
# ts 3 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 0.41809871792793274                             0.008320818655192852 0.06455594301223755
# ts 4 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 0.807043194770813                             0.010732279159128666 0.09585940837860107
# ts 5 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 1.4280009269714355                             0.013488643802702427 0.13749302923679352
# ts 6 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 2.3585779666900635                             0.016643401235342026 0.1928657442331314
# ts 7 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 3.7185001373291016                             0.020239757373929024 0.2665114402770996
# ts 8 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 9.453747749328613                             0.09241635352373123 18.55542755126953
# ts 9 head_segment 4186305 segINDEX 0 segID 4186305                             FNL:qdc vel depth 16.32366180419922                             0.10338518023490906 33.06656265258789
# ts 0 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 1.1095139980316162                             0.11307013034820557 0.011035695672035217
# ts 1 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 3.6233553886413574                             0.19168752431869507 0.024677475914359093
# ts 2 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 6.4319305419921875                             0.27368640899658203 0.042821042239665985
# ts 3 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 9.168210983276367                             0.3632998466491699 0.06695199012756348
# ts 4 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 11.463623046875                             0.46278882026672363 0.09904614835977554
# ts 5 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 13.015966415405273                             0.5735031962394714 0.1417313814163208
# ts 6 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 14.040398597717285                             1.5143206119537354 1.0530719757080078
# ts 7 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 13.230857849121094                             2.0421831607818604 2.865640163421631
# ts 8 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 11.848735809326172                             2.0007176399230957 2.646495819091797
# ts 9 head_segment 4185613 segINDEX 0 segID 4185613                             FNL:qdc vel depth 10.056188583374023                             1.9388995170593262 2.34991192817688
# ts 0 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 0.5011529326438904                             0.06054789572954178 0.010234556160867214
# ts 1 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 1.7628074884414673                             0.10502348840236664 0.02361195906996727
# ts 2 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 3.565394401550293                             0.15140582621097565 0.04140390455722809
# ts 3 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 5.925556182861328                             0.2023557722568512 0.06506719440221786
# ts 4 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 8.80931568145752                             0.25939029455184937 0.09653937071561813
# ts 5 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 12.107101440429688                             0.3235695958137512 0.13839736580848694
# ts 6 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 18.096925735473633                             0.8128771781921387 0.786407470703125
# ts 7 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 25.907615661621094                             1.4850834608078003 5.761466026306152
# ts 8 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 29.65133285522461                             1.5174436569213867 6.356189250946045
# ts 9 head_segment 4185613 segINDEX 1 segID 4185667                             FNL:qdc vel depth 30.555435180664062                             1.5246520042419434 6.495216369628906
# ts 0 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 0.0682617649435997                             0.002437972230836749 0.010021491907536983
# ts 1 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 0.19384486973285675                             0.004254924599081278 0.02332858368754387
# ts 2 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 0.38566288352012634                             0.006147530395537615 0.0410270169377327
# ts 3 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 0.656161904335022                             0.008226527832448483 0.06456593424081802
# ts 4 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 1.0206458568572998                             0.010555005632340908 0.09587269276380539
# ts 5 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 1.4961562156677246                             0.013177501037716866 0.13751068711280823
# ts 6 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 2.099290370941162                             0.01612379215657711 0.1928892284631729
# ts 7 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 3.863957405090332                             0.056922778487205505 4.179412841796875
# ts 8 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 7.1640167236328125                             0.0787588581442833 17.18773651123047
# ts 9 head_segment 4185613 segINDEX 2 segID 4186307                             FNL:qdc vel depth 11.750181198120117                             0.08377018570899963 21.43838882446289
# ts 0 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 0.238594651222229                             0.024729697033762932 0.010205317288637161
# ts 1 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 0.6997260451316833                             0.04305984079837799 0.023573072627186775
# ts 2 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 1.3966178894042969                             0.06233897805213928 0.04135219007730484
# ts 3 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 2.335826873779297                             0.08375544846057892 0.06499841064214706
# ts 4 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 3.5097107887268066                             0.10807984322309494 0.0964478850364685
# ts 5 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 4.896043300628662                             0.135963574051857 0.13827569782733917
# ts 6 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 9.216463088989258                             0.6503044962882996 2.952432155609131
# ts 7 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 12.285114288330078                             0.6878209710121155 3.549588441848755
# ts 8 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 14.917699813842773                             0.7168582081794739 4.112661361694336
# ts 9 head_segment 4186309 segINDEX 0 segID 4186309                             FNL:qdc vel depth 19.367238998413086                             0.755215048789978 5.035220146179199
# 4186309 completed
# ... in 0.03639531135559082 seconds.
# ordered reach computation complete
# ... in 0.04069828987121582 seconds.
